# %% [markdown]
# ### Number of rows using provided csv counting code

# %%
data_path = "data/2017-18-crdc-data/2017-18 Public-Use Files/Data/LEA/CRDC/CSV/LEA Characteristics.csv"

f = open(data_path, "r" , encoding = "cp1252")

counter = 0

for x in f :
    counter = counter + 1

print(counter)
# Out:
# 17616

# %% [markdown]
# ### Number of rows using pandas

# %%
import pandas as pd

data_path = "data/2017-18-crdc-data/2017-18 Public-Use Files/Data/LEA/CRDC/CSV/LEA Characteristics.csv"
dataframe = pd.read_csv(data_path, encoding="cp1252")

num_rows = dataframe.shape[0]
print(num_rows)
# column_headers = dataframe.columns.tolist()
# print("LEA Characteristics.csv")
# print(len(column_headers))
# print(column_headers)
# Out:
# 17604
# /var/folders/0c/crj9sgv91050s1n9_jdqs0mc0000gn/T/ipykernel_19561/1181226061.py:4: DtypeWarning: Columns (2,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv(data_path, encoding="cp1252")

# %% [markdown]
# ### Find wack lines with python

# %%
data_path = "data/2017-18-crdc-data/2017-18 Public-Use Files/Data/LEA/CRDC/CSV/LEA Characteristics.csv"

with open(data_path, "r", encoding="cp1252") as f:
    content = f.read()
    
# Split the content by lines
lines = content.split("\n")

# Keep track of multi-line fields
inside_quotes = False
multi_line_data = ""

for line in lines:
    # Count the number of double quotes in the line
    num_quotes = line.count('"')
    
    # If there's an odd number of quotes, we toggle the inside_quotes flag
    if num_quotes % 2 != 0:
        inside_quotes = not inside_quotes
    
    # If we're inside a multi-line field, accumulate the line; otherwise, reset
    if inside_quotes:
        multi_line_data += line + "\n"
    else:
        if multi_line_data:
            multi_line_data += line
            print("Multi-line Row:\n", multi_line_data)
            multi_line_data = ""
# Out:
# Multi-line Row:
#  "PA","PENNSYLVANIA","4200887","Reach Cyber CS","750 East Park Drive","Harrisburg","17111","No",1929,0,1,"Yes","Yes","Yes","JANE","SWAN","7177048437
# ","jswan@reach.connectionsacademy.org","JANE","SWAN","7177048437
# ","jswan@reach.connectionsacademy.org","JANE","SWAN","7177048437
# ","jswan@reach.connectionsacademy.org","No","Yes","Yes","www.connexus.com","No","-9","No","-9","-9","-9","-9","-9","-9","-9",-9,-9,-9,-9,"-9","-9","-9","-9","Yes","Yes","No","No","No"
# Multi-line Row:
#  "VA","VIRGINIA","5101470","FREDERICK CO PBLC SCHS","P O Box 3508","Winchester","22604","Yes",13529,113,18,"Yes","Yes","Yes","JOHN","LINABURG
# ","540-662-3888","linaburj@fcpsk12.net","CHARLES
# ","PEEELING
# ","540-662-3888
# ","peelingc@fcpsk12.net","MICHELLE
# ","SANDY
# ","540-662-3888
# ...

# %% [markdown]
# ### Python row count with no encoding

# %%
data_path = "data/2017-18-crdc-data/2017-18 Public-Use Files/Data/LEA/CRDC/CSV/LEA Characteristics.csv"

try:
    with open(data_path, "rb") as f:
        counter = 0
        for line in f:
            counter += 1
            try:
                decoded_line = line.decode('utf-8')
                print(decoded_line.strip())  # Print each line
            except UnicodeDecodeError:
                print(f"Encoding issue at line {counter}")
                break  # Exit the loop if there's an encoding issue
except FileNotFoundError:
    print("File not found. Please check the file path.")
# Out:
# "LEA_STATE","LEA_STATE_NAME","LEAID","LEA_NAME","LEA_ADDRESS","LEA_CITY","LEA_ZIP","CJJ","LEA_ENR","LEA_ENR_NONLEAFAC","LEA_SCHOOLS","LEA_CRCOORD_SEX_IND","LEA_CRCOORD_RAC_IND","LEA_CRCOORD_DIS_IND","LEA_CRCOORD_SEX_FN","LEA_CRCOORD_SEX_LN","LEA_CRCOORD_SEX_PH","LEA_CRCOORD_SEX_EM","LEA_CRCOORD_RAC_FN","LEA_CRCOORD_RAC_LN","LEA_CRCOORD_RAC_PH","LEA_CRCOORD_RAC_EM","LEA_CRCOORD_DIS_FN","LEA_CRCOORD_DIS_LN","LEA_CRCOORD_DIS_PH","LEA_CRCOORD_DIS_EM","LEA_DESEGPLAN","LEA_HBPOLICY_IND","LEA_HBPOLICYURL_IND","LEA_HBPOLICY_URL","LEA_ECE_IND","LEA_ECE_NONIDEA","LEA_PS_IND","LEA_PS_FULLDAYFREE","LEA_PS_FULLDAYCOST","LEA_PS_PARTDAYFREE","LEA_PS_PARTDAYCOST","LEA_PSENR_NONIDEA_A3","LEA_PSENR_NONIDEA_A4","LEA_PSENR_NONIDEA_A5","LEA_PSENR_A2","LEA_PSENR_A3","LEA_PSENR_A4","LEA_PSENR_A5","LEA_PSELIG_ALL","LEA_PSELIG_IDEA","LEA_PSELIG_TITLEI","LEA_PSELIG_LOWINC","LEA_KG_IND","LEA_KG_FULLDAYFREE","LEA_KG_FULLDAYCOST","LEA_KG_PARTDAYFREE","LEA_KG_PARTDAYCOST"
# ...

# %% [markdown]
# ## Question 4

# %%
fpath = "./data/EDGE_GEOCODE_PUBLICLEA_1718/EDGE_GEOCODE_PUBLICLEA_1718/EDGE_GEOCODE_PUBLICLEA_1718.csv"
f = open (fpath, "r", encoding = "cp1252" )

counter = 0;
for x in f :
    counter = counter + 1
print (counter)
# Out:
# 18843

# %% [markdown]
# find rows with pandas

# %%
data_path = "./data/EDGE_GEOCODE_PUBLICLEA_1718/EDGE_GEOCODE_PUBLICLEA_1718/EDGE_GEOCODE_PUBLICLEA_1718.csv" 
dataframe = pd.read_csv(data_path, encoding="cp1252")

num_rows = dataframe.shape[0]
print(num_rows)
# Out:
# 18842

# %% [markdown]
# ### find rows with csv module

# %%
import csv

data_path = "./data/EDGE_GEOCODE_PUBLICLEA_1718/EDGE_GEOCODE_PUBLICLEA_1718/EDGE_GEOCODE_PUBLICLEA_1718.csv"

with open(data_path, 'r') as csv_file:
    reader = csv.reader(csv_file)
    for row in reader:
        counter += 1
print(f"Total number of rows in the CSV file: {counter}")
# Out:
# Total number of rows in the CSV file: 56529

# %% [markdown]
# ### Find diff with pandas

# %%
print(difference[-5:])
print(edge[-5:])
print(lea[-5:])
# Out:
# ['4901140', '4901170', '4901200', '5000001', '5000002']
# [6000030, 6600002, 7200030, 7800002, 7800030]
# [5680251, 5680252, 5680254, 5680255, 7200030]

# %% [markdown]
# ### Make sql

# %%
import sqlite3

conn = sqlite3.connect('crdc.db')

c = conn.cursor()
