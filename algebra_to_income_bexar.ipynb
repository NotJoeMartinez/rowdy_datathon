# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
data = pd.read_csv('track_trace_income_algebra_1.csv')

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['INCOME'], data['ALGEBRA_1_PASSERS'], color='blue', edgecolor='black')
plt.title('Relationship between Predicted Income and Number of High Schoolers Passing Algebra 1')
plt.xlabel('Predicted Income for Census Tract Area')
plt.ylabel('Number of High Schoolers Passing Algebra 1')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)


# z = np.polyfit(data['INCOME'], data['ALGEBRA_1_PASSERS'], 1)
# p = np.poly1d(z)
# plt.plot(data['INCOME'], p(data['INCOME']), "r--")

plt.show()
